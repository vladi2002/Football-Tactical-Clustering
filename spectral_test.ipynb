# %%
from spectral_eval import run_full_test_suite
from graph import ZoneTransformer

zt = ZoneTransformer()
results = run_full_test_suite(match_ids=[2058017, 2058019, 2058020])
# Out:
# ================================================================================
# TACTICAL PATTERN DISCOVERY - FULL TEST SUITE
# ================================================================================
#
# [1/5] Loading match data...
#
# Loading match 2058017...
#
# Loading match 2058019...
#   Error loading match 2058019: Input file not found: https://raw.githubusercontent.com/koenvo/wyscout-soccer-match-event-dataset/main/processed-v2/files/2058019.json
#
# Loading match 2058020...
#   Error loading match 2058020: Input file not found: https://raw.githubusercontent.com/koenvo/wyscout-soccer-match-event-dataset/main/processed-v2/files/2058020.json
#
# Loaded 2 graphs total
#
# [2/5] Running Experiment 1: Parameter Sensitivity...
#
# ================================================================================
# EXPERIMENT 1: PARAMETER SENSITIVITY (k)
# ================================================================================
#
# Testing k=3...
#   Silhouette: 0.267 ± 0.007
#   Calinski-Harabasz: 15.7 ± 1.7
#
# Testing k=4...
#   Silhouette: 0.298 ± 0.002
#   Calinski-Harabasz: 17.9 ± 2.7
#
# Testing k=5...
#   Silhouette: 0.263 ± 0.038
#   Calinski-Harabasz: 15.5 ± 0.0
#
# Testing k=6...
#   Silhouette: 0.273 ± 0.049
#   Calinski-Harabasz: 16.2 ± 1.6
#
# Testing k=7...
#   Silhouette: 0.268 ± 0.050
#   Calinski-Harabasz: 16.5 ± 1.8
# [3/5] Running Experiment 2: Similarity Weights...
#
# ================================================================================
# EXPERIMENT 2: SIMILARITY WEIGHT COMBINATIONS
# ================================================================================
#
# Testing: Structure-only
#   α=1.0, β=0.0, γ=0.0
#   Silhouette: 0.000 ± 0.012
#
# Testing: Structure+Edge
#   α=0.6, β=0.4, γ=0.0
#   Silhouette: 0.082 ± 0.021
#
# Testing: Structure+Node
#   α=0.6, β=0.0, γ=0.4
#   Silhouette: 0.321 ± 0.024
#
# Testing: Balanced
#   α=0.4, β=0.3, γ=0.3
#   Silhouette: 0.263 ± 0.038
#
# Testing: Edge-focused
#   α=0.2, β=0.6, γ=0.2
#   Silhouette: 0.196 ± 0.025
# /opt/anaconda3/envs/graphml/lib/python3.13/site-packages/sklearn/manifold/_spectral_embedding.py:328: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# [4/5] Running Experiment 3: Team Consistency...
#
# ================================================================================
# EXPERIMENT 3: TEAM TACTICAL CONSISTENCY
# ================================================================================
#
# No team consistency results (need ≥2 matches per team). Skipping Experiment 3 charts.
#
# [5/5] Running Experiment 4: Pattern Interpretation...
#
# ================================================================================
# EXPERIMENT 4: PATTERN INTERPRETATION
# ================================================================================
#
# ================================================================================
# EXAMPLE 1: France (Match 2058017)
# ================================================================================
#
# ================================================================================
# TACTICAL PATTERN DISCOVERY
# ================================================================================
#
# ================================================================================
# PATTERN 0: 10 zones
# ================================================================================
# Zones: [11, 16, 20, 12, 13, 40, 17, 22, 21, 7]
# Names: ['LEFT_HALF_DEF_THIRD_DEEP', 'LEFT_HALF_DEF_THIRD', 'LEFT_WING_MID_THIRD_DEF', 'CENTER_DEF_THIRD_DEEP', 'RIGHT_HALF_DEF_THIRD_DEEP']...
#
# Spatial profile:
#   • Center: (44.3, 63.5)
#   • Spread: X=24.5, Y=20.7
#   • Region: CENTRAL MIDFIELD
#
# Connectivity:
#   • Internal edges: 36
#   • External edges: 45
#   • Internal flow strength: 56
#   • Total events: 215
#
# Player roles:
#   • GK: 0.00%, DF: 0.00%, MD: 0.00%, FW: 90.00%
#
# 📋 Interpretation: CENTRAL MIDFIELD PATTERN (possession/progression)
#
# ================================================================================
# PATTERN 1: 7 zones
# ================================================================================
# Zones: [18, 14, 19, 23, 29, 24, 28]
# Names: ['RIGHT_HALF_DEF_THIRD', 'RIGHT_WING_DEF_THIRD_DEEP', 'RIGHT_WING_DEF_THIRD', 'RIGHT_HALF_MID_THIRD_DEF', 'RIGHT_WING_MID_THIRD_ATT']...
#
# Spatial profile:
#   • Center: (53.6, 17.4)
#   • Spread: X=17.5, Y=9.2
#   • Region: FLANK MIDFIELD
#
# Connectivity:
#   • Internal edges: 17
#   • External edges: 28
#   • Internal flow strength: 34
#   • Total events: 142
#
# Player roles:
#   • GK: 0.00%, DF: 0.00%, MD: 0.00%, FW: 0.00%
#
# 📋 Interpretation: FLANK PLAY PATTERN (wing-based)
#
# ================================================================================
# PATTERN 2: 8 zones
# ================================================================================
# Zones: [10, 2, 6, 9, 8, 3, 5, 0]
# Names: ['LEFT_WING_DEF_THIRD_DEEP', 'CENTER_DEF_BOX', 'LEFT_HALF_DEF_PENALTY', 'RIGHT_WING_DEF_PENALTY', 'RIGHT_HALF_DEF_PENALTY']...
#
# Spatial profile:
#   • Center: (9.7, 57.4)
#   • Spread: X=6.7, Y=30.8
#   • Region: WIDE DEFENSIVE
#
# Connectivity:
#   • Internal edges: 4
#   • External edges: 15
#   • Internal flow strength: 5
#   • Total events: 52
#
# Player roles:
#   • GK: 0.00%, DF: 0.00%, MD: 0.00%, FW: 37.50%
#
# 📋 Interpretation: WIDE PLAY PATTERN (wing-based)
#
# ================================================================================
# PATTERN 3: 6 zones
# ================================================================================
# Zones: [36, 32, 34, 37, 33, 38]
# Names: ['LEFT_HALF_ATT_PENALTY', 'CENTER_ATT_THIRD', 'RIGHT_WING_ATT_THIRD', 'CENTER_ATT_PENALTY', 'RIGHT_HALF_ATT_THIRD']...
#
# Spatial profile:
#   • Center: (93.0, 39.6)
#   • Spread: X=4.0, Y=20.2
#   • Region: CENTRAL ATTACKING
#
# Connectivity:
#   • Internal edges: 4
#   • External edges: 3
#   • Internal flow strength: 5
#   • Total events: 10
#
# Player roles:
#   • GK: 0.00%, DF: 0.00%, MD: 0.00%, FW: 0.00%
#
# 📋 Interpretation: GENERAL PLAY PATTERN
#
# ================================================================================
# PATTERN 4: 7 zones
# ================================================================================
# Zones: [15, 25, 27, 26, 31, 30, 35]
# Names: ['LEFT_WING_DEF_THIRD', 'LEFT_WING_MID_THIRD_ATT', 'CENTER_MID_THIRD_ATT', 'LEFT_HALF_MID_THIRD_ATT', 'LEFT_HALF_ATT_THIRD']...
#
# Spatial profile:
#   • Center: (77.6, 79.4)
#   • Spread: X=16.7, Y=14.5
#   • Region: FLANK ATTACKING
#
# Connectivity:
#   • Internal edges: 8
#   • External edges: 13
#   • Internal flow strength: 11
#   • Total events: 74
#
# Player roles:
#   • GK: 0.00%, DF: 0.00%, MD: 0.00%, FW: 0.00%
#
# 📋 Interpretation: FLANK PLAY PATTERN (wing-based)
# ================================================================================
# EXAMPLE 2: Croatia (Match 2058017)
# ================================================================================
#
# ================================================================================
# TACTICAL PATTERN DISCOVERY
# ================================================================================
#
# ================================================================================
# PATTERN 0: 9 zones
# ================================================================================
# Zones: [23, 24, 13, 18, 19, 14, 29, 34, 28]
# Names: ['RIGHT_HALF_MID_THIRD_DEF', 'RIGHT_WING_MID_THIRD_DEF', 'RIGHT_HALF_DEF_THIRD_DEEP', 'RIGHT_HALF_DEF_THIRD', 'RIGHT_WING_DEF_THIRD']...
#
# Spatial profile:
#   • Center: (54.3, 17.7)
#   • Spread: X=21.7, Y=9.2
#   • Region: FLANK MIDFIELD
#
# Connectivity:
#   • Internal edges: 35
#   • External edges: 33
#   • Internal flow strength: 83
#   • Total events: 224
#
# Player roles:
#   • GK: 0.00%, DF: 100.00%, MD: 0.00%, FW: 0.00%
#
# 📋 Interpretation: FLANK PLAY PATTERN (wing-based)
#
# ================================================================================
# PATTERN 1: 8 zones
# ================================================================================
# Zones: [16, 10, 6, 12, 11, 15, 7, 8]
# Names: ['LEFT_HALF_DEF_THIRD', 'LEFT_WING_DEF_THIRD_DEEP', 'LEFT_HALF_DEF_PENALTY', 'CENTER_DEF_THIRD_DEEP', 'LEFT_HALF_DEF_THIRD_DEEP']...
#
# Spatial profile:
#   • Center: (23.7, 65.6)
#   • Spread: X=11.8, Y=20.2
#   • Region: FLANK DEFENSIVE
#
# Connectivity:
#   • Internal edges: 29
#   • External edges: 31
#   • Internal flow strength: 80
#   • Total events: 185
#
# Player roles:
#   • GK: 0.00%, DF: 25.00%, MD: 0.00%, FW: 0.00%
#
# 📋 Interpretation: FLANK PLAY PATTERN (wing-based)
#
# ================================================================================
# PATTERN 2: 10 zones
# ================================================================================
# Zones: [40, 33, 38, 35, 32, 30, 39, 37, 31, 36]
# Names: ['OUTSIDE', 'RIGHT_HALF_ATT_THIRD', 'RIGHT_HALF_ATT_PENALTY', 'LEFT_WING_ATT_PENALTY', 'CENTER_ATT_THIRD']...
#
# Spatial profile:
#   • Center: (94.1, 59.0)
#   • Spread: X=4.3, Y=29.2
#   • Region: WIDE ATTACKING
#
# Connectivity:
#   • Internal edges: 17
#   • External edges: 10
#   • Internal flow strength: 26
#   • Total events: 75
#
# Player roles:
#   • GK: 0.00%, DF: 40.00%, MD: 0.00%, FW: 0.00%
#
# 📋 Interpretation: WIDE PLAY PATTERN (wing-based)
#
# ================================================================================
# PATTERN 3: 6 zones
# ================================================================================
# Zones: [5, 2, 9, 4, 1, 3]
# Names: ['LEFT_WING_DEF_PENALTY', 'CENTER_DEF_BOX', 'RIGHT_WING_DEF_PENALTY', 'RIGHT_WING_DEF_BOX', 'LEFT_HALF_DEF_BOX']...
#
# Spatial profile:
#   • Center: (5.7, 43.2)
#   • Spread: X=3.8, Y=30.6
#   • Region: WIDE DEFENSIVE
#
# Connectivity:
#   • Internal edges: 3
#   • External edges: 5
#   • Internal flow strength: 3
#   • Total events: 18
#
# Player roles:
#   • GK: 0.00%, DF: 0.00%, MD: 0.00%, FW: 0.00%
#
# 📋 Interpretation: WIDE PLAY PATTERN (wing-based)
#
# ================================================================================
# PATTERN 4: 7 zones
# ================================================================================
# Zones: [17, 22, 26, 25, 20, 21, 27]
# Names: ['CENTER_DEF_THIRD', 'CENTER_MID_THIRD_DEF', 'LEFT_HALF_MID_THIRD_ATT', 'LEFT_WING_MID_THIRD_ATT', 'LEFT_WING_MID_THIRD_DEF']...
#
# Spatial profile:
#   • Center: (63.4, 67.9)
#   • Spread: X=11.9, Y=17.0
#   • Region: FLANK MIDFIELD
#
# Connectivity:
#   • Internal edges: 31
#   • External edges: 39
#   • Internal flow strength: 113
#   • Total events: 271
#
# Player roles:
#   • GK: 0.00%, DF: 100.00%, MD: 0.00%, FW: 0.00%
#
# 📋 Interpretation: FLANK PLAY PATTERN (wing-based)
# ================================================================================
# TEST SUITE COMPLETE
# ================================================================================
# Total graphs analyzed: 2
# Results saved:
#   - experiment1_k_sensitivity.png
#   - experiment2_weights.png
#   - experiment3_consistency.png
#   - Pattern visualizations displayed
