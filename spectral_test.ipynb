# %%
from spectral_eval import run_team_consistency_test

results = run_team_consistency_test("France", k=5)
# Out:
# ...
# TACTICAL CONSISTENCY TEST: France
# ...
# Scanning for team 'France'...
#   ✓ Found France in match 2058003 (home)
#   ✓ Found France in match 2058010 (away)
#   ✓ Found France in match 2058014 (home)
#   ✓ Found France in match 2058017 (home)
#
# ✅ Found 4 matches for France
#
# Processing match 2058003...
#   ✓ Built graph: 550 events, 37 nodes, 210 edges
#
# Processing match 2058010...
#   ✓ Built graph: 811 events, 41 nodes, 257 edges
#
# Processing match 2058014...
#   ✓ Built graph: 558 events, 40 nodes, 216 edges
#
# Processing match 2058017...
#   ✓ Built graph: 494 events, 38 nodes, 194 edges
#
# ...
# SUMMARY: Loaded 4 graphs for France
# ...
#   • Matches: 4
#   • Total events: 2413
#   • Team ID: 4418
#
# ...
# DISCOVERING PATTERNS
# ...
#
# [1/4] Match 2058003, full: 550 events
#
# [2/4] Match 2058010, full: 811 events
#
# [3/4] Match 2058014, full: 558 events
#
# [4/4] Match 2058017, full: 494 events
#
# ...
# COMPUTING CONSISTENCY
# ...
#
# ...
# CONSISTENCY RESULTS: France
# ...
#
# Graphs analyzed: 4
# ...
